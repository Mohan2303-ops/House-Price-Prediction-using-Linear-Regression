# %% [markdown]
# ## Step 5 — EDA - target distribution

# %%
train_df = X_train.copy()
train_df[target] = y_train

fig, ax = plt.subplots(figsize=(7, 4))
sns.histplot(train_df[target], kde=True, ax=ax)
ax.set_title('Target Distribution — Price (in $100,000s)')
ax.set_xlabel('Price')
plt.show()
